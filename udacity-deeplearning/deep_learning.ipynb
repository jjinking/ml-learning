# %%
# %matplotlib inline

# %%
"""Softmax."""

scores = [3.0, 1.0, 0.2]
scores2 = [[3.0, 3, 3], [1, 1, 1.0], [0.2, 0.2,0.2]]

import numpy as np

def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    scores_exp = np.exp(x)
    return scores_exp / np.sum(scores_exp, axis=0)

print(softmax(scores))
print(softmax(scores2))
# Out:
# [ 0.8360188   0.11314284  0.05083836]
# [[ 0.8360188   0.8360188   0.8360188 ]
#  [ 0.11314284  0.11314284  0.11314284]
#  [ 0.05083836  0.05083836  0.05083836]]

# %%
# Plot softmax curves
import matplotlib.pyplot as plt
x = np.arange(-2.0, 6.0, 0.1)
scores = np.vstack([x, np.ones_like(x), 0.2 * np.ones_like(x)])

plt.plot(x, softmax(scores).T, linewidth=2)
plt.show()

# %%
plt.plot(x, softmax(scores * 10).T, linewidth=2)
plt.show()

# %%
plt.plot(x, softmax(scores / 10).T, linewidth=2)
plt.show()
